# %% [markdown]
# ## Sesiones 1 y 2 - Introducción a Python

# %% [markdown]
# ![python.png](attachment:python.png)
# En estas dos primeras sesiones, intentaremos aprender cómo funciona el lenguaje de programación Python. A continuación, se muestran ejemplos de las funciones y utilidades más básicas. Con estos ejemplos y buscando información en internet, familiarízate con el entorno de programación

# %% [markdown]
# ### La función ***print*** permite mostrar texto en pantalla

# %%
print("Hola")
# Out:
# Hola

# %% [markdown]
# ### Python permite declarar variables

# %%
a = 2
b = 3
a,b
# Out:
# (2, 3)

# %% [markdown]
# ### Python puede ser usado como calculadora

# %%
c = a + b
d = a*b
e = a/b
c,d,e
# Out:
# (5, 6, 0.6666666666666666)

# %% [markdown]
# ### Los bucles *for*

# %%
for i in range(3):
    print(i)
print("Programa terminado")
# Out:
# 0
# 1
# 2
# Programa terminado

# %% [markdown]
# ### Los bucles *while*

# %%
i=0
while i <= 3:
    print(i)
    i = i+1
print("Programa terminado")
# Out:
# 0
# 1
# 2
# 3
# Programa terminado

# %% [markdown]
# ### True y False

# %%
2*3==6
# Out:
# True

# %%
2*3==7
# Out:
# False

# %% [markdown]
# ### Definir funciones

# %%
def MiPrimeraFuncion(N):    
    resultado = 0
    for i in range(N):
        resultado = resultado+(i+1)       
    print("La suma de los",N," primeros números es",resultado)

# %% [markdown]
# ### Utilizar funciones previamente definidas

# %%
MiPrimeraFuncion(10)
# Out:
# La suma de los 10  primeros números es 55

# %% [markdown]
# ![erastostenes.png](attachment:erastostenes.png)

# %% [markdown]
# ## Ejercicio propuesto
# Con los ejemplos anteriores y **buscando toda la información que necesites en la red**, intenta crear un pequeño programa con el que llevar a cabo el algoritmo de *Criba de Erastóstones*.
# El algoritmo consiste en listar todos los valores entre 2 (primer número primo) y N. En primer lugar, se tachan todos los múltiplos de 2. A continuación, se toma el primer número no tachado de la lista (será el 3) y se tachan todos sus múltiplos, y así sucesivamente. Al final, todos los números que queden sin tachar serán números primos.
